# %% [markdown]
# This notebook is to evaluate galaxies which have low SNR but which nevertheless have sufficiently high log(SFR), log(Mstar), and log(sSFR) to meet out Virgo sample cuts.

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from photutils.aperture import CircularAperture
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy.wcs.utils import skycoord_to_pixel
from astropy.table import Table
import os
from astropy.io import fits
import glob
from scipy.stats import binned_statistic_2d
homedir=os.getenv("HOME")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
#image path location
im_path = homedir+'/Desktop/zinput_im/'
#image name format: unwise-VFIDxxxx-w3-img-m.fits
#(I am using FITS files from ~3 years ago, for consistency.)

# %%
#this function replicates (as closely as possible) the SNR routine I created ~3 years ago.
#NOTE. I HAVE SINCE DELETED THE RELEVANT DIRECTORY. IGNORE THIS CELL.
def surface_brightness(galaxy_table,im_path):
    surf15 = np.zeros(len(galaxy_table),dtype=float)
    surf30 = np.zeros(len(galaxy_table),dtype=float)
    objnames = galaxy_table['VFID']
    for n in galaxy_table:
        im = glob.glob(f'{im_path}unwise-{n['VFID_V1']}*')[0]
        #open the image...
        hdu_im=fits.open(im)[0]   
        #WCS header information
        wcs_w3 = WCS(hdu_im) 
        img_len = len(hdu_im.data)
        position = (int(img_len/2.),int(img_len/2.))   #(x,y) pixel coords
        len_arcsec = np.abs(hdu_im.header['NAXIS1']*hdu_im.header['CD1_1'])*3600.
        arcsec_per_pixel = len_arcsec/hdu_im.header['NAXIS1']     #should be 2.75"/px for W1, W3
        #15" and 30" apertures
        radius_15 = 15/arcsec_per_pixel
        radius_30 = radius_15*2
        #note --> the masks act as 'cookie cutters,' isolating the image region within the given radius
        aper15 = CircularAperture(position,radius_15)
        mask15 = aper15.to_mask(method='center')   #'cookie cutter'
        aper30 = CircularAperture(position,radius_30)
        mask30 = aper30.to_mask(method='center')
        data15_im = mask15.multiply(hdu_im.data)
        data30_im = mask30.multiply(hdu_im.data)
        data15_im = data15_im[data15_im!=0.]
        data30_im = data30_im[data30_im!=0.]
        signal15 = np.sqrt(np.sum(data15_im**2))
        signal30 = np.sqrt(np.sum(data30_im**2))
        surf15[galaxy_table['VFID_V1']==n['VFID_V1']] = round(signal15/(np.pi*radius_15**2),1)
        surf30[galaxy_table['VFID_V1']==n['VFID_V1']] = round(signal30/(np.pi*radius_30**2),1)
    return surf15, surf30

# %%
def comp_snr():
    #read in new tables --> only trim galaxies with "bad" photometry (according to table flag)
    vf_all=Table.read(homedir+'/Desktop/galfit_files/VF_WISESIZE_v2.fits') #has snr15, snr30 values
    phot_all = Table.read(homedir+'/Desktop/galfit_files/vf_v2_legacy_ephot.fits') #new SNR and success flag

    vf = vf_all[phot_all['photFlag']]
    phot = phot_all[phot_all['photFlag']]
    
    w3_sig = phot['FLUX_AP03_W3']
    w3_noise = 1/np.sqrt(phot['FLUX_IVAR_AP03_W3'])

    snr15 = vf['snr15']
    snr15_flag = vf['snr15_flag']
    snr30_flag = vf['snr30_flag']
    snrphot = w3_sig/w3_noise
    snrphot_flag = (snrphot<10)

    plt.figure()
    plt.scatter(snr15, snrphot, alpha=0.5, s=15, label='SNR>10')
    plt.scatter(snr15[~snr15_flag & ~snr30_flag], 
                snrphot[~snr15_flag & ~snr30_flag], 
                alpha=0.5, s=15, label='My SNR<10')
    plt.scatter(snr15[snrphot_flag], snrphot[snrphot_flag],alpha=0.5,s=15,label='AP03 SNR<10')
    plt.axhline(10,color='green', linestyle='--',label='AP03 SNR<10 Cutoff')
    plt.axvline(10,color='orange',linestyle='--',label='My SNR<10 Cutoff')

    plt.axline((0, 0), slope=1, color='indigo',label='1-to-1')
    
    plt.xlabel('My SNR [15"]',fontsize=13)
    plt.ylabel('Phot SNR [AP03]',fontsize=13)
    plt.legend()
    plt.xscale('log')
    plt.yscale('log')

    plt.show()

    print(f'# AP03 Galaxies SNR>10: {len(snrphot[~snrphot_flag])}')
    print(f'# My Galaxies SNR>10: {len(vf_all[vf_all['snr15_flag'] | vf_all['snr30_flag']])}')

# %%
vfmain = Table.read(homedir+'/Desktop/v2-20220820/vf_v2_main.fits')
vf=Table.read(homedir+'/Desktop/galfit_files/VF_WISESIZE_v2.fits')
magphys = Table.read(homedir+'/Desktop/galfit_files/vf-altphot.fits')
phot = Table.read(homedir+'/Desktop/galfit_files/vf_v2_legacy_ephot.fits')   #also has a phot success flag!
logsfr = magphys['combined_logSFR_med']
logmass = magphys['combined_logMstar_med']
w3_dat = Table.read(homedir+'/Desktop/galfit_files/vf_v2_galfit_W3-fixBA.fits')
w1_dat = Table.read(homedir+'/Desktop/galfit_files/vf_v2_galfit_W1-fixBA.fits')

# %%
V1_VFID = vfmain['VFID_V1']
vf.add_column(V1_VFID,name='VFID_V1')

# %%
err_flag = (magphys['magphys_flag']) &  (magphys['combined_logSFR_med']!=0.)
sample_flag = (vf['massflag']) & (vf['SFRflag']) & (vf['sSFR_flag'])
qual_flag = err_flag & sample_flag

# %%
snr15_flag, snr30_flag = vf['snr15_flag'], vf['snr30_flag']

# %%
vf = vf[qual_flag]
logmass = logmass[qual_flag]
logsfr = logsfr[qual_flag]
snr15 = vf['snr15']
snr30 = vf['snr30']
snr15_flag = snr15_flag[qual_flag]
snr30_flag = snr30_flag[qual_flag]
phot = phot[qual_flag]
w3_dat = w3_dat[qual_flag]
w1_dat = w1_dat[qual_flag]

# %%
plt.subplots(1,2,figsize=(9,3))
plt.subplot(121)
plt.hist(logmass[snr15_flag | snr30_flag],bins=30,label='SNR>10',alpha=0.3)
plt.hist(logmass[~snr15_flag & ~snr30_flag],bins=30,label='SNR<10',alpha=0.3)
plt.legend(loc='upper left')
plt.xlabel('log(Mstar)',fontsize=13)
plt.subplot(122)
plt.hist(logsfr[snr15_flag | snr30_flag],bins=30,label='SNR>10',alpha=0.3)
plt.hist(logsfr[~snr15_flag & ~snr30_flag],bins=30,label='SNR<10',alpha=0.3)
plt.legend()
plt.xlabel('log(SFR)',fontsize=13)

plt.savefig(homedir+'/Desktop/hist.png',dpi=100,bbox_inches='tight', pad_inches=0.2)
plt.show()

# %%
plt.subplots(1,2,figsize=(9,3))
plt.subplot(121)
plt.hist(surf15[snr15_flag | snr30_flag],bins=500,label='SNR>10',alpha=0.3)
plt.hist(surf15[~snr15_flag & ~snr30_flag],bins=50,label='SNR<10',alpha=0.3)
plt.legend()
plt.xlabel('Surface Brightness [15"]',fontsize=13)
plt.xscale('log')
plt.yscale('log')

plt.subplot(122)
plt.hist(surf30[snr15_flag | snr30_flag],bins=500,label='SNR>10',alpha=0.3)
plt.hist(surf30[~snr15_flag & ~snr30_flag],bins=50,label='SNR<10',alpha=0.3)
plt.legend()
plt.xlabel('Surface Brightness [30"]',fontsize=13)
plt.xscale('log')
plt.yscale('log')

print(f'# SNR>10: {len(surf15[snr15_flag | snr30_flag])}')
print(f'# SNR<10: {len(surf15[~snr15_flag & ~snr30_flag])}')

plt.savefig(homedir+'/Desktop/hist.png',dpi=100,bbox_inches='tight', pad_inches=0.2)
plt.show()
# Out:
# # SNR>10: 659
# # SNR<10: 485

# %%
plt.subplots(1,2,figsize=(9,3))
plt.subplots_adjust(wspace=0.3)

plt.subplot(121)
plt.scatter(snr15,surf15)
plt.xlabel('SNR [15"]',fontsize=13)
plt.ylabel('Surface Brightness [15"]',fontsize=13)
plt.yscale('log')

plt.subplot(122)
plt.scatter(snr30,surf30)
plt.xlabel('SNR [30"]',fontsize=13)
plt.ylabel('Surface Brightness [30"]',fontsize=13)
plt.yscale('log')

plt.savefig(homedir+'/Desktop/hist.png',dpi=100,bbox_inches='tight', pad_inches=0.2)
plt.show()

# %%
'''
estimate of the fraction of galaxies that make it through to the final sample. 
the mass completeness limit for the sample (>9.3) is very different than for the full sample (>8.26).
'''
nbins=20
mybins=np.linspace(8.3,11,nbins)
mybins_sfr=np.linspace(-1,1,nbins)

plt.subplots(1,2,figsize=(10,4))
plt.subplot(121)
mtot=plt.hist(logmass,bins=mybins,alpha=0.3,label='All')
m15=plt.hist(logmass[snr15_flag | snr30_flag],bins=mybins,alpha=0.3,label='SNR>10')
mratio=m15[0]/mtot[0]
plt.plot(mybins[1:],mratio*100,label='Fraction SNR>10')
plt.legend()
plt.xlabel('log(Mstar)',fontsize=13)


plt.subplot(122)
stot=plt.hist(logsfr,bins=mybins_sfr,alpha=0.3,label='All')
s15=plt.hist(logsfr[snr15_flag | snr30_flag],bins=mybins_sfr,alpha=0.3,label='SNR>10')
sratio=s15[0]/stot[0]
plt.plot(mybins_sfr[1:],sratio*100,label='Fraction SNR>10')
plt.legend()
plt.xlabel('log(SFR)',fontsize=13)
plt.savefig(homedir+'/Desktop/hist.png',dpi=100)
plt.show()
# Out:
# /var/folders/gx/q5wqxlgs0rgfm6f87vgxlgyw4s52w0/T/ipykernel_2612/1184557124.py:13: RuntimeWarning: invalid value encountered in divide
#   mratio=m15[0]/mtot[0]

# %%
def bin_data(x, y, bins):
    counts, x_edges, y_edges = np.histogram2d(x, y, bins=bins)
    return counts, x_edges, y_edges

def calculate_ratio(counts1, counts2):
    ratio = counts2 / (counts1)
    return ratio

def plot_ratio(ratio, x_edges, y_edges):
    plt.figure(figsize=(8, 6))
    plt.imshow(ratio.T, origin='lower', aspect='auto',
               extent=[x_edges[0], x_edges[-1], y_edges[0], y_edges[-1]],
               cmap='viridis')
    plt.colorbar(label='Ratio of SNR>10 / Total')
    plt.xlabel('log(Mstar)',fontsize=13)
    plt.ylabel('log(SFR)',fontsize=13)
    plt.show()
    
nbins = 20
massbins=np.linspace(8.3,11,nbins)
sfrbins=np.linspace(-1.,1.,nbins)
mybins=[massbins,sfrbins]

x2=logmass[snr15_flag | snr30_flag]
y2=logsfr[snr15_flag | snr30_flag]
x1=logmass
y1=logsfr

# Bin the data
counts1, x_edges, y_edges = bin_data(x1, y1, mybins)
counts2, x_edges, y_edges = bin_data(x2, y2, mybins)

# Calculate the ratio
ratio = calculate_ratio(counts1, counts2)

# Plot the resulting ratios
plot_ratio(ratio, x_edges, y_edges)

'''
Sample completeness in SFR v. stellar mass plot. Need log(Mstar)>9.3 for mass completeness according to sample 
(and NOT the total VFS).
'''
# Out:
# /var/folders/gx/q5wqxlgs0rgfm6f87vgxlgyw4s52w0/T/ipykernel_2612/3271245600.py:6: RuntimeWarning: invalid value encountered in divide
#   ratio = counts2 / (counts1)
# '\nSample completeness in SFR v. stellar mass plot. Need log(Mstar)>9.3 for mass completeness according to sample \n(and NOT the total VFS).\n'

# %%
x=phot['FLUX_AP01_W3']
plt.scatter(x,surf15,alpha=0.4)
plt.yscale('log')
plt.xscale('log')
#expect there to be some correlation

# %%
plt.scatter(logmass,x,c=snr15,vmin=3.,vmax=20.,alpha=0.5,s=10)
plt.yscale('log')
plt.colorbar(label='SNR [15"]')
plt.xlabel('log(Mstar)',fontsize=13)
plt.ylabel('AP02 Flux (W3)',fontsize=13)
plt.ylim(10.,1.e5)
plt.xlim(8.,11.)
plt.figure()
plt.scatter(logmass,x,c=snr30,vmin=3.,vmax=20.,alpha=0.5,s=10)
plt.yscale('log')
plt.colorbar(label='SNR [30"]')
plt.xlabel('log(Mstar)',fontsize=13)
plt.ylabel('AP02 Flux (W3)',fontsize=13)
plt.ylim(10.,1.e5)
plt.xlim(8.,11.)
# Out:
# (8.0, 11.0)

# %% [markdown]
# -----

# %% [markdown]
# ## Mon, June 3 (2024)

# %%
err_flag = (w1_dat['CNumerical_Error']) | (w3_dat['CNumerical_Error']) | (w1_dat['CXC']==0.0) | (w3_dat['CXC']==0.0) #ALL ERRORS
sersic_flag = (w1_dat['CN']>6) | (w3_dat['CN']>6) #unphysical
size_flags = (~err_flag) & (~sersic_flag)

# %%
plt.scatter(logmass,logsfr,s=20,alpha=0.4,label='VFW Sample')
plt.scatter(logmass[~snr15_flag & ~snr30_flag],logsfr[~snr15_flag & ~snr30_flag],alpha=0.3,s=20,facecolor='red',edgecolor='red',
           label='My SNR<10 Galaxies') #c=snr15,vmin=3.,vmax=20.,

plt.xlabel('log(Mstar)',fontsize=13)
plt.ylabel('log(SFR)',fontsize=13)

x_p = np.linspace(np.min(logmass),np.max(logmass),1000)
y_p = 0.8*x_p - 8.32
plt.plot(x_p,y_p,color='black',label='Main Sequence fit',alpha=0.7,linewidth=3,zorder=2)
plt.xlim(8.2,11)
plt.ylim(-1.2,)
plt.legend()
plt.show()

# %%
w3_sig = phot['FLUX_AP03_W3']
w3_noise = 1/np.sqrt(phot['FLUX_IVAR_AP03_W3'])

snrphot = w3_sig/w3_noise

snrphot_flag = (snrphot<10)

plt.figure(figsize=(10,8))
plt.scatter(logmass,logsfr,s=30,alpha=0.6,label='VFW Sample',c=snrphot,vmin=0,vmax=100)
cb = plt.colorbar()
cb.set_label('AP03 SNR',fontsize=13)
#plt.scatter(logmass[snrphot<10],logsfr[snrphot<10],alpha=0.3,s=20,facecolor='red',edgecolor='red',
#           label='Phot SNR<10 Galaxies') #c=snr15,vmin=3.,vmax=20.,
plt.scatter(logmass[~size_flags],logsfr[~size_flags],marker='s',s=90,alpha=0.8,
            edgecolor='black',facecolor='None')

plt.xlabel('log(Mstar)',fontsize=13)
plt.ylabel('log(SFR)',fontsize=13)

x_p = np.linspace(np.min(logmass),np.max(logmass),1000)
y_p = 0.8*x_p - 8.32
plt.plot(x_p,y_p,color='black',label='Main Sequence fit',alpha=0.7,linewidth=3,zorder=2)
plt.xlim(8.2,11)
plt.ylim(-1.2,)
plt.legend()
plt.show()

# %%
plt.scatter(snr15[size_flags], w3_dat['CRE'][size_flags], 
            c=w3_dat['CRE'][size_flags]/w1_dat['CRE'][size_flags],vmin=0,vmax=1.7,alpha=0.6)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('SNR [15"]',fontsize=13)
plt.ylabel(r'R$_{12}$ [px]',fontsize=13)
cb = plt.colorbar()
cb.set_label(label=r'R$_{12}$/R$_{3.4}$',size=13)

# %%
comp_snr()
# Out:
# # AP03 Galaxies SNR>10: 2083
# # My Galaxies SNR>10: 1095

# %%
plt.scatter(snrphot[size_flags], w3_dat['CRE'][size_flags]/w1_dat['CRE'][size_flags],alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('AP03 SNR',fontsize=13)
plt.ylabel(r'R$_{12}$/R$_{3.4}$',fontsize=13)
plt.ylim(.5,2)
plt.show()
