# %%
#appending fourth image block to galfit output mosaic (contains residual with same flux stretch as that of
#the WISE signal -- data -- image)
import os
import numpy as np
from astropy.io import fits
from astropy.visualization import simple_norm
from astropy.wcs import WCS
from astropy.table import Table
from astropy.io import ascii
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.stats import scoreatpercentile
import glob

homedir = os.getenv("HOME")

# %%
#vfcut.fits for SNR>10 subsample, sga_cut.fits for PA,BA fixed

vf = Table.read(homedir+'/vfcut.fits',format='ascii')
dummycat = Table.read(homedir+'/dummycat.fits',format='ascii')

# %%
def four_panel_mosaic(index,sample=vf,dummycat=dummycat):
    
    galname = sample['VFID'][index]
    objname = sample['prefix'][index]
    filename = glob.glob(homedir+'/output_fits/'+galname+'*.fits')[0]
    
    print(index)
    ind = np.where(sample['VFID'] == galname)[0]
    ind = int(ind)
    
    if vf['VFID'][ind] in dummycat['central galaxy']:
        ncomp = len(np.where(dummycat['central galaxy'] == galname)[0])
        pngname = objname+'-unwise-w3-{}Comp-galfit-out-conv.png'.format(ncomp+1)
    else:
        pngname = objname+'-unwise-w3-1Comp-galfit-out-conv.png'
    
    
    image,h = fits.getdata(filename,1,header=True)
    model = fits.getdata(filename,2)
    residual = fits.getdata(filename,3)

    wcs = WCS(h)

    images = [image,model,residual,residual]
    titles = ['image','model','residual (img stretch)','residual (res stretch)']

    percentile1=.5
    percentile2=99.5
    p1residual=5
    p2residual=99

    v1 = [scoreatpercentile(image,percentile1),
        scoreatpercentile(image,percentile1),
        scoreatpercentile(image,percentile1),
        scoreatpercentile(residual,p1residual)]

    v2 = [scoreatpercentile(image,percentile2),
        scoreatpercentile(image,percentile2),        
        scoreatpercentile(image,percentile2),
        scoreatpercentile(residual,p2residual)]

    norms = [simple_norm(image,'asinh',max_percent=percentile2),
            simple_norm(image,'asinh',max_percent=percentile2),
            simple_norm(image,'asinh',max_percent=percentile2),
            simple_norm(residual,'linear',max_percent=p2residual)]

    plt.figure(figsize=(14,6))
    plt.subplots_adjust(wspace=.0)
    for i,im in enumerate(images):
        plt.subplot(1,4,i+1,projection=wcs)
        plt.imshow(im,origin='lower',vmin=v1[i],vmax=v2[i],norm=norms[i])
        plt.xlabel('RA')
        if i == 0:
            plt.ylabel('DEC')
        else:
            plt.ylabel(' ')
            ax = plt.gca()
            ax.set_yticks([])     
        plt.title(titles[i],fontsize=16)
    
    
    plt.savefig(pngname)
    plt.close()

# %%
#output_mosaics for vf, output_mosaics_fixed for sga
os.chdir(homedir+'/output_mosaics')

for index in range(465,len(vf)):
    four_panel_mosaic(index)
# Out:
# 465
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 466
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 467
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 468
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 469
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 470
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 471
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 472
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 473
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 474
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 475
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 476
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 477
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 478
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 479
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 480
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 481
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 482
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 483
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 484
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 485
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 486
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 487
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 488
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 489
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 490
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 491
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 492
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 493
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 494
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 495
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 496
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 497
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 498
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 499
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 500
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 501
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 502
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 503
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 504
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 505
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 506
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 507
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 508
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 509
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 510
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 511
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 512
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 513
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 514
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 515
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 516
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 517
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 518
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 519
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 520
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 521
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 522
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 523
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 524
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 525
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 526
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 527
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 528
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 529
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 530
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 531
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 532
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 533
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 534
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 535
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 536
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 537
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 538
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 539
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 540
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 541
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 542
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 543
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 544
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 545
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 546
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 547
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 548
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 549
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 550
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 551
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 552
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 553
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 554
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 555
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 556
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 557
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 558
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 559
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 560
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 561
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 562
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 563
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 564
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 565
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 566
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 567
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 568
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 569
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 570
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 571
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 572
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 573
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 574
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 575
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 576
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 577
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 578
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# 579
# /Users/k215c316/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3d0f233c94a8> in <module>
#       3
#       4 for index in range(465,len(vf)):
# ----> 5     four_panel_mosaic(index)
#
# <ipython-input-11-b64231cd005a> in four_panel_mosaic(index, sample, dummycat)
#      60
#      61
# ---> 62     plt.savefig(pngname)
#      63     plt.close()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     965     fig = gcf()
#     966     res = fig.savefig(*args, **kwargs)
# --> 967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#     969
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def get_width_height(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2778
#    2779             self.patch.draw(renderer)
# -> 2780             mimage._draw_list_compositing_images(
#    2781                 renderer, self, artists, self.suppressComposite)
#    2782
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py in draw(self, renderer, **kwargs)
#     457         self.coords.frame._update_patch_path()
#     458
# --> 459         super().draw(renderer, **kwargs)
#     460
#     461         self._drawn = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py in draw(self, renderer, *args, **kwargs)
#      43
#      44     def draw(self, renderer, *args, **kwargs):
# ---> 45         self.axes.draw_wcsaxes(renderer)
#      46
#      47
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/core.py in draw_wcsaxes(self, renderer)
#     413             coords.frame.update()
#     414             for coord in coords:
# --> 415                 coord._draw_grid(renderer)
#     416
#     417         for coords in self._all_coords:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/coordinate_helpers.py in _draw_grid(self, renderer)
#     565         renderer.open_group('grid lines')
#     566
# --> 567         self._update_ticks()
#     568
#     569         if self.grid_lines_kwargs['visible']:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/astropy/visualization/wcsaxes/coordinate_helpers.py in _update_ticks(self)
#     726                 with np.errstate(invalid='ignore'):
#     727                     w1[w2 - w1 > 180.] += 360
# --> 728                     w2[w1 - w2 > 180.] += 360
#     729
#     730                 if self._coord_scale_to_deg is not None:
#
# KeyboardInterrupt:

# %%
np.where(vf['VFID']=='VFID2171')
# Out:
# (array([412]),)

# %%
#PA,BA fixed failure indices: 412,464
#PA,BA free failure indices:
